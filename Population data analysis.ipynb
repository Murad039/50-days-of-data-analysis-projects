# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:\\datafile\\population_data.csv')
df.head()
# Out:
#          Country  Population  Urban Population  Rural Population
# 0          China   144616277       62233489.02      8.238279e+07
# 1          India   161802610       93703729.99      6.809888e+07
# 2  United States   199096104       89266811.49      1.098293e+08
# 3      Indonesia   192423285       58981078.45      1.334422e+08
# 4       Pakistan   122038765       78004077.98      4.403469e+07

# %%
df.dtypes
# Out:
# Country              object
# Population            int64
# Urban Population    float64
# Rural Population    float64
# dtype: object

# %%
df.shape
# Out:
# (20, 4)

# %%
df.isnull().sum()
# Out:
# Country             0
# Population          0
# Urban Population    0
# Rural Population    0
# dtype: int64

# %%
df['Country'].duplicated().sum()
# Out:
# np.int64(0)

# %%
colm_range = df['Population'].max() - df['Population'].min()
colm_range
# Out:
# 159664488

# %%
m = df['Population'].mean()
m
# Out:
# np.float64(127368421.75)

# %%
me = df['Population'].median()
me
# Out:
# 141602917.5

# %%
df_pop = pd.read_csv('D:\\datafile\\population_data.csv')
df_pop.head()
# Out:
#          Country  Population  Urban Population  Rural Population
# 0          China   144616277       62233489.02      8.238279e+07
# 1          India   161802610       93703729.99      6.809888e+07
# 2  United States   199096104       89266811.49      1.098293e+08
# 3      Indonesia   192423285       58981078.45      1.334422e+08
# 4       Pakistan   122038765       78004077.98      4.403469e+07

# %%
tot = df['Population'].sum()
tot
# Out:
# np.int64(2547368435)

# %%
avg = df['Population'].mean()
avg
# Out:
# np.float64(127368421.75)

# %%
big_pop = df['Population'].idxmax()
big_population = df['Country'][big_pop]
big_population
# Out:
# 'United States'

# %%
small_urb = df['Urban Population'].idxmin()
small_urb_pop = df['Country'][small_urb]
small_urb_pop
# Out:
# 'Turkey'

# %%
plt.figure(figsize = (12, 8))

plt.hist(df['Population'],bins = 10, density = 1, alpha = 0.7)

plt.title(' suhdfbisadhbfi', fontsize = 20)
plt.show()
