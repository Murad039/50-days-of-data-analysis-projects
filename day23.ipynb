# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer

# %%
names = ['kelly', np.nan, 'jon', 'ken', 'Tim', 'Pal']
grades = [30, 40, 43, 55, np.nan, 33]
age = [12, np.nan, 18, 17, np.nan, 16]

df = pd.DataFrame({"Names": names, "Grades": grades, "Age":age})
df
# Out:
#    Names  Grades   Age
# 0  kelly    30.0  12.0
# 1    NaN    40.0   NaN
# 2    jon    43.0  18.0
# 3    ken    55.0  17.0
# 4    Tim     NaN   NaN
# 5    Pal    33.0  16.0

# %%
df.isnull().sum()
# Out:
# Names     1
# Grades    1
# Age       2
# dtype: int64

# %%
df2 =df.copy()

imputer_names = SimpleImputer( strategy = 'constant', fill_value='Paul', )
imputer_grades = SimpleImputer( strategy = 'mean')
imputer_age = SimpleImputer( strategy = 'median')

# %%
df2[['Names']] = imputer_names.fit_transform(df2[['Names']])
df2[['Grades']] = imputer_grades.fit_transform(df2[['Grades']])
df2[['Age']] = imputer_age.fit_transform(df2[['Age']])
df2
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df2[['Names']] = imputer_names.fit_transform(df2[['Names']])
#       2 df2[['Grades']] = imputer_grades.fit_transform(df2[['Grades']])
#       3 df2[['Age']] = imputer_age.fit_transform(df2[['Age']])
#
# File C:\ana\envs\myenv\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# ...
